# %% [markdown]
# 参考:
#
# [1.4. Matplotlib: plotting — Scipy lecture notes](http://www.scipy-lectures.org/intro/matplotlib/matplotlib.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # 1 Simple Plot

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# %% [markdown]
# document:
#
# - [Pyplot tutorial — Matplotlib 2.0.2 documentation](http://matplotlib.org/users/pyplot_tutorial.html)
# - [pyplot — Matplotlib 2.0.2 documentation](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)

# %% [markdown]
# ## 1.1 Plot with default setting

# %%
plt.plot(X, C)
plt.plot(X, S)

plt.show()

# %% [markdown]
# ## 1.2  Instantiating defaults 修改
#
# [Customizing matplotlib — Matplotlib 2.0.2 documentation](http://matplotlib.org/users/customizing.html)

# %%
# Figure size: 8x6 inches, 80dots per inch
plt.figure(figsize=(8, 6), dpi=80)

# %%
# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)

C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color='blue', linewidth=1.0, linestyle='-')

plt.plot(X, S, color='green', linewidth=1.0, linestyle='-')

# set x limits
plt.xlim(-4.0, 4.0)

# Set x ticks
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

# Set y limits
plt.ylim(-1.0, 1.0)

# Set y ticks
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

# save figure using 72dots per inch
plt.savefig("exercise_1.png", dpi=72)
plt.show()

# %% [markdown]
# ## 1.3 Changing colors and line widths
#
# - [Pyplot tutorial — Matplotlib 2.0.2 documentation](http://matplotlib.org/users/pyplot_tutorial.html#controlling-line-properties)
# - [Line-API: artist Module — Matplotlib 2.1.0 documentation](http://matplotlib.org/api/artist_api.html#matplotlib.lines.Line2D)

# %%
plt.figure(figsize=(10, 6), dpi=80)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## 1.4. Setting limits
#
# - [xlim()](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xlim)
# - [ylim() command](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.ylim)

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

# %% [markdown]
# ## 1.5. Setting ticks
#
# - [xticks() command](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xticks)
# - [yticks() command](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.yticks)
# - [Tick container](http://matplotlib.org/users/artists.html#axis-container)
# - [Tick locating and formatting](http://matplotlib.org/api/ticker_api.html)

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

plt.xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
# Out:
# ([<matplotlib.axis.YTick at 0xa029908>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# ## 1.6. Setting tick labels
#
# - [Working with text](http://matplotlib.org/users/index_text.html)
# - [set_xticklabels()](http://matplotlib.org/api/axes_api.html?#matplotlib.axes.Axes.set_xticklabels)
# - [set_yticklabels()](http://matplotlib.org/api/axes_api.html?#matplotlib.axes.Axes.set_yticklabels)

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

plt.xticks([-np.pi, -np.pi/2, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])
# Out:
# ([<matplotlib.axis.YTick at 0xa769d30>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# ## 1.7. Moving spines

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-")

plt.xticks([-np.pi, -np.pi/2, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

ax = plt.gca() # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# %% [markdown]
# ## 1.8 Adding a legend

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.xticks([-np.pi, -np.pi/2, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

plt.legend(loc='upper left')

# %% [markdown]
# ## 1.9 Annotate some points
#
# 在曲线上取点标记

# %%
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(S.min() * 1.1, S.max() * 1.1)
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sine")

plt.xticks([-np.pi, -np.pi/2, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

# move spines
ax = plt.gca() # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# annotate some points
t = 2 * np.pi / 3

plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t], [0, np.sin(t)], color='red', linewidth=2.5, linestyle='--')
plt.scatter([t, ], [np.sin(t), ], 50, color='red')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$', 
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.2"))

# %% [markdown]
# `plt.scatter`, `xytext` 暂且不理解. 先继续走下去

# %% [markdown]
# ## 1.10 Devil is in the details.

# %%
## 1.10 Devil is in the details.
plt.figure(figsize=(8, 5), dpi=80)
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-",  label="sine")

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.yticks([-1, 1],
          [r'$-1$', r'$+1$'])

plt.legend(loc='upper left')

t = 2*np.pi/3
plt.plot([t, t], [0, np.cos(t)],
        color='blue', linewidth=1.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(10, 30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t], [0, np.sin(t)],
        color='red', linewidth=1.5, linestyle="--")
plt.scatter([t, ], [np.sin(t), ], 50, color ='red')
plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$', xy=(t, np.cos(t)),
            xycoords='data', xytext=(-90, -50),
            textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# devil is in detail
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65))

plt.show()

# %% [markdown]
# [Go-ON](http://www.scipy-lectures.org/intro/matplotlib/matplotlib.html#beyond-this-tutorial)
