# %% [markdown]
# # Porject Demographic Data Analyzer
# link: https://www.freecodecamp.org/learn/data-analysis-with-python/data-analysis-with-python-projects/demographic-data-analyzer

# %%
import pandas as pd

# %%
df = pd.read_csv('adult_data.csv', delimiter=',')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.race.unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
len(df.race.unique())
# Out:
# 5

# %%
average_age_men = round(df.age.mean(), 1)
average_age_men
# Out:
# 38.6

# %%
caseload = df.shape[0] # total numbers of people

# %%
caseload
# Out:
# 32561

# %%
percentage_bachelors = round(df.education.value_counts().Bachelors / caseload * 100.0, 1)

# %%
percentage_bachelors
# Out:
# 16.4

# %%
mask1 = (df['education'] == 'Bachelors') & (df['salary'] == '>50K')
df[mask1]
# Out:
#        age     workclass  fnlwgt  education  education-num  \
# 9       42       Private  159449  Bachelors             13
# 11      30     State-gov  141297  Bachelors             13
# 25      56     Local-gov  216851  Bachelors             13
# 45      57   Federal-gov  337895  Bachelors             13
# 53      50   Federal-gov  251585  Bachelors             13
# ...    ...           ...     ...        ...            ...
# 32464   45  Self-emp-inc  173664  Bachelors             13
# 32530   35             ?  320084  Bachelors             13
# 32533   54       Private  337992  Bachelors             13
# 32536   34       Private  160216  Bachelors             13
# 32538   38       Private  139180  Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 9      Married-civ-spouse  Exec-managerial        Husband               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
mask2 = (df['education'] == 'Masters') & (df['salary'] == '>50K')
df[mask2]
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 8       31           Private   45781   Masters             14
# 19      43  Self-emp-not-inc  292175   Masters             14
# 100     76           Private  124191   Masters             14
# 135     38       Federal-gov  125933   Masters             14
# 164     45  Self-emp-not-inc  201080   Masters             14
# ...    ...               ...     ...       ...            ...
# 32457   33           Private  139057   Masters             14
# 32480   41           Private  201495   Masters             14
# 32504   50           Private  208630   Masters             14
# 32513   46           Private   42972   Masters             14
# 32554   53           Private  321865   Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# ...

# %%
mask3 = (df['education'] == 'Doctorate') & (df['salary'] == '>50K')
df[mask3]
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 20      40           Private  193524  Doctorate             16
# 63      42           Private  116632  Doctorate             16
# 89      43       Federal-gov  410867  Doctorate             16
# 96      48  Self-emp-not-inc  191277  Doctorate             16
# 189     58         State-gov  109567  Doctorate             16
# ...    ...               ...     ...        ...            ...
# 32287   54         Local-gov   34832  Doctorate             16
# 32326   48           Private  123075  Doctorate             16
# 32429   51         Local-gov  203334  Doctorate             16
# 32532   34           Private  204461  Doctorate             16
# 32539   71                 ?  287372  Doctorate             16
#
#            marital-status       occupation   relationship   race     sex  \
# 20     Married-civ-spouse   Prof-specialty        Husband  White    Male
# ...

# %%
higher_education = df[mask1].shape[0] + df[mask2].shape[0] + df[mask3].shape[0]
higher_education
# Out:
# 3486

# %%
mask = ((df['education'] == 'Bachelors') | 
        (df['education'] == 'Masters') | 
        (df['education'] == 'Doctorate')) & (df['salary'] == '>50K')

# %%
df[mask].shape[0]
# Out:
# 3486

# %%
mask_50K = df['salary'] == '>50K'
lower_education = df[mask_50K].shape[0] - higher_education

# %%
lower_education
# Out:
# 4355

# %%
higher_education_rich = round(higher_education / caseload * 100.0, 1)
lower_education_rich = round(lower_education / caseload * 100.0, 1)

# %%
higher_education_rich
# Out:
# 10.7

# %%
lower_education_rich
# Out:
# 13.4

# %%
# What is the minimum number of hours a person works per week 
# (hours-per-week feature)?
min_work_hours = df['hours-per-week'].min()

# %%
min_work_hours
# Out:
# 1

# %%
# What percentage of the people who 
# work the minimum number of hours per week 
# have a salary of >50K?
mask = (df['salary'] == '>50K') & (df['hours-per-week'] == min_work_hours)
num_min_workers = df[mask].shape[0]
rich_percentage = round(num_min_workers / (higher_education + lower_education) * 100.0, 1)

# %%
rich_percentage
# Out:
# 0.0

# %%
num_min_workers
# Out:
# 2

# %% [markdown]
# # What country has the highest percentage of people that earn >50K?

# %%
df.groupby(['native-country', 'salary'])['age'].count().reset_index(level='salary')
# Out:
#                salary   age
# native-country
# ?               <=50K   437
# ?                >50K   146
# Cambodia        <=50K    12
# Cambodia         >50K     7
# Canada          <=50K    82
# ...               ...   ...
# United-States    >50K  7171
# Vietnam         <=50K    62
# Vietnam          >50K     5
# Yugoslavia      <=50K    10
# Yugoslavia       >50K     6
#
# [82 rows x 2 columns]

# %%
mask = df['salary'] == '>50K'

# %%
df2 = df[mask].groupby('native-country')['salary'].count().reset_index()
df2
# Out:
#         native-country  salary
# 0                    ?     146
# 1             Cambodia       7
# 2               Canada      39
# 3                China      20
# 4             Columbia       2
# 5                 Cuba      25
# 6   Dominican-Republic       2
# 7              Ecuador       4
# 8          El-Salvador       9
# 9              England      30
# 10              France      12
# 11             Germany      44
# 12              Greece       8
# 13           Guatemala       3
# 14               Haiti       4
# 15            Honduras       1
# 16                Hong       6
# 17             Hungary       3
# 18               India      40
# 19                Iran      18
# 20             Ireland       5
# 21               Italy      25
# 22             Jamaica      10
# 23               Japan      24
# 24                Laos       2
# 25              Mexico      33
# 26           Nicaragua       2
# 27                Peru       2
# 28         Philippines      61
# ...

# %%
df3 = df2[df2['salary'] == df2['salary'].max()]

# %%
df3
# Out:
#    native-country  salary
# 37  United-States    7171

# %%
df3.iloc[0]['native-country']
# Out:
# 'United-States'

# %%
country = df3['native-country']

# %%
country.iloc[0]
# Out:
# 'United-States'

# %%
type(country.iloc[0])
# Out:
# str

# %%
num_highest_country = df2['salary'].max()

# %%
highest_earning_country = df3.iloc[0]['native-country']

# %%
highest_earning_country
# Out:
# 'United-States'

# %%
num_highest_country
# Out:
# 7171

# %%
highest_earning_country_percentage = round(num_highest_country / caseload * 100.0, 1)

# %%
highest_earning_country_percentage
# Out:
# 22.0

# %% [markdown]
# # Identify the most popular occupation for those who earn >50K in India.

# %%
mask = df['salary'] == '>50K'

# %%
df2 = df[mask].groupby(['native-country', 'occupation'])['salary'].count().reset_index()

# %%
df2
# Out:
#     native-country         occupation  salary
# 0                ?                  ?       4
# 1                ?       Adm-clerical       9
# 2                ?       Craft-repair      21
# 3                ?    Exec-managerial      31
# 4                ?  Handlers-cleaners       3
# ..             ...                ...     ...
# 212        Vietnam     Prof-specialty       1
# 213     Yugoslavia    Exec-managerial       2
# 214     Yugoslavia    Farming-fishing       1
# 215     Yugoslavia  Machine-op-inspct       1
# 216     Yugoslavia      Other-service       2
#
# [217 rows x 3 columns]

# %%
df3 = df2[df2['native-country'] == 'India']

# %%
df3
# Out:
#     native-country        occupation  salary
# 94           India      Adm-clerical       1
# 95           India   Exec-managerial       8
# 96           India     Other-service       2
# 97           India    Prof-specialty      25
# 98           India             Sales       1
# 99           India      Tech-support       2
# 100          India  Transport-moving       1

# %%
india_occupation_max = df3['salary'].max()

# %%
mask = df3['salary'] == india_occupation_max
df3[mask].iloc[0]['occupation']
# Out:
# 'Prof-specialty'

# %% [markdown]
# # How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.

# %%
df_race = df.groupby('race')['salary'].count().reset_index()
df_race_copy = df_race.copy()
df_race_copy
# Out:
#                  race  salary
# 0  Amer-Indian-Eskimo     311
# 1  Asian-Pac-Islander    1039
# 2               Black    3124
# 3               Other     271
# 4               White   27816

# %%
df_race_copy = df_race_copy.set_index('race')

# %%
df_race_copy
# Out:
#                     salary
# race
# Amer-Indian-Eskimo     311
# Asian-Pac-Islander    1039
# Black                 3124
# Other                  271
# White                27816

# %%
df_race_copy = df_race_copy.set_axis(['total_num'], axis=1)

# %%
my_series = df_race_copy.squeeze() # dataframe to series

# %%
my_series
# Out:
# race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# Name: total_num, dtype: int64

# %%
race_count = df_race.squeeze()

# %%
race_count.
# Out:
#                  race  salary
# 0  Amer-Indian-Eskimo     311
# 1  Asian-Pac-Islander    1039
# 2               Black    3124
# 3               Other     271
# 4               White   27816

# %%
race_count.to_list()
# Out:
# [311, 1039, 3124, 271, 27816]

# %%
df_race2 = df.groupby('race').count()

# %%
df_race2
# Out:
#                       age  workclass  fnlwgt  education  education-num  \
# race
# Amer-Indian-Eskimo    311        311     311        311            311
# Asian-Pac-Islander   1039       1039    1039       1039           1039
# Black                3124       3124    3124       3124           3124
# Other                 271        271     271        271            271
# White               27816      27816   27816      27816          27816
#
#                     marital-status  occupation  relationship    sex  \
# race
# Amer-Indian-Eskimo             311         311           311    311
# Asian-Pac-Islander            1039        1039          1039   1039
# Black                         3124        3124          3124   3124
# Other                          271         271           271    271
# White                        27816       27816         27816  27816
#
#                     capital-gain  capital-loss  hours-per-week  \
# race
# ...

# %% [markdown]
# # How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.

# %%
df['age'].any()
# Out:
# True

# %%
df.all()
# Out:
# age                True
# workclass          True
# fnlwgt             True
# education          True
# education-num      True
# marital-status     True
# occupation         True
# relationship       True
# race               True
# sex                True
# capital-gain      False
# capital-loss      False
# hours-per-week     True
# native-country     True
# salary             True
# dtype: bool

# %%
df['age'].mean()
# Out:
# 38.58164675532078

# %%
df_sex = df.groupby('sex')['age'].count()

# %%
df_sex
# Out:
# sex
# Female    10771
# Male      21790
# Name: age, dtype: int64

# %%
df_male = df[df['sex'] == 'Male']

# %%
df_male
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32553   32           Private  116138       Masters             14
# 32554   53           Private  321865       Masters             14
# 32555   22           Private  310152  Some-college             10
# 32557   40           Private  154374       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# ...

# %%
df_male.age.mean()
# Out:
# 39.43354749885268

# %%
df_male2 = df[df['sex'] == 'Male']['age']

# %%
df_male2
# Out:
# 0        39
# 1        50
# 2        38
# 3        53
# 7        52
#          ..
# 32553    32
# 32554    53
# 32555    22
# 32557    40
# 32559    22
# Name: age, Length: 21790, dtype: int64

# %%
df_male2.mean()
# Out:
# 39.43354749885268

# %%
df.groupby('education')['age'].count()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5355
# Doctorate         413
# HS-grad         10501
# Masters          1723
# Preschool          51
# Prof-school       576
# Some-college     7291
# Name: age, dtype: int64

# %%
mask = df['salary'] == '>50K'
len(df[mask])
# Out:
# 7841

# %%
df[mask].shape
# Out:
# (7841, 15)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_country = df.groupby(['native-country', 'salary'])['age'].count().reset_index()

# %%
df_country.rename(columns={'age': 'sum'}).head()
# Out:
#   native-country salary  sum
# 0              ?  <=50K  437
# 1              ?   >50K  146
# 2       Cambodia  <=50K   12
# 3       Cambodia   >50K    7
# 4         Canada  <=50K   82

# %%
df_only_country = df.groupby(['native-country'])['age'].count().reset_index()
df_only_country.head()
# Out:
#   native-country  age
# 0              ?  583
# 1       Cambodia   19
# 2         Canada  121
# 3          China   75
# 4       Columbia   59

# %%
mask = df_country['salary'] == '>50K'
df_country[mask].head()
# Out:
#   native-country salary  age
# 1              ?   >50K  146
# 3       Cambodia   >50K    7
# 5         Canada   >50K   39
# 7          China   >50K   20
# 9       Columbia   >50K    2

# %%
df_all = df_country[mask]
df_all.reset_index(inplace=True)
df_all.head()
# Out:
#    index native-country salary  age
# 0      1              ?   >50K  146
# 1      3       Cambodia   >50K    7
# 2      5         Canada   >50K   39
# 3      7          China   >50K   20
# 4      9       Columbia   >50K    2

# %%
df_all['age'].head()
# Out:
# 0    146
# 1      7
# 2     39
# 3     20
# 4      2
# Name: age, dtype: int64

# %%
df_only_country['>50K'] = df_all['age']
df_only_country.head()
# Out:
#   native-country  age   >50K
# 0              ?  583  146.0
# 1       Cambodia   19    7.0
# 2         Canada  121   39.0
# 3          China   75   20.0
# 4       Columbia   59    2.0

# %%
df_country_50k = df_only_country.copy()

# %%
df_country_50k['percentage'] = df_country_50k['>50K'] / df_country_50k['age'] * 100

# %%
df_country_50k.head()
# Out:
#   native-country  age   >50K  percentage
# 0              ?  583  146.0   25.042882
# 1       Cambodia   19    7.0   36.842105
# 2         Canada  121   39.0   32.231405
# 3          China   75   20.0   26.666667
# 4       Columbia   59    2.0    3.389831

# %%
mask = df_country_50k['percentage'] == df_country_50k['percentage'].max()
df_country_50k[mask]
# Out:
#    native-country  age    >50K    percentage
# 37       Thailand   18  7171.0  39838.888889

# %%
df = pd.read_csv('adult_data.csv', delimiter=',')

# %%
df_country = df.groupby(['native-country'])['age'].count().reset_index()

# %%
df_country.head()
# Out:
#   native-country  age
# 0              ?  583
# 1       Cambodia   19
# 2         Canada  121
# 3          China   75
# 4       Columbia   59

# %%
df_country.shape
# Out:
# (42, 2)

# %%
df_country.tail()
# Out:
#      native-country    age
# 37         Thailand     18
# 38  Trinadad&Tobago     19
# 39    United-States  29170
# 40          Vietnam     67
# 41       Yugoslavia     16

# %%
df_sal = df.groupby(['native-country', 'salary'])['age'].count().reset_index()
df_sal.size
# Out:
# 246

# %%
df_sal.head()
# Out:
#   native-country salary  age
# 0              ?  <=50K  437
# 1              ?   >50K  146
# 2       Cambodia  <=50K   12
# 3       Cambodia   >50K    7
# 4         Canada  <=50K   82

# %%
df_50k = df_sal[df_sal['salary'] != '>50K']

# %%
df_50k.head()
# Out:
#   native-country salary  age
# 0              ?  <=50K  437
# 2       Cambodia  <=50K   12
# 4         Canada  <=50K   82
# 6          China  <=50K   55
# 8       Columbia  <=50K   57

# %%
df_50k.tail()
# Out:
#      native-country salary    age
# 72         Thailand  <=50K     15
# 74  Trinadad&Tobago  <=50K     17
# 76    United-States  <=50K  21999
# 78          Vietnam  <=50K     62
# 80       Yugoslavia  <=50K     10

# %%
df_50k.reset_index()
# Out:
#     index              native-country salary    age
# 0       0                           ?  <=50K    437
# 1       2                    Cambodia  <=50K     12
# 2       4                      Canada  <=50K     82
# 3       6                       China  <=50K     55
# 4       8                    Columbia  <=50K     57
# 5      10                        Cuba  <=50K     70
# 6      12          Dominican-Republic  <=50K     68
# 7      14                     Ecuador  <=50K     24
# 8      16                 El-Salvador  <=50K     97
# 9      18                     England  <=50K     60
# 10     20                      France  <=50K     17
# 11     22                     Germany  <=50K     93
# 12     24                      Greece  <=50K     21
# 13     26                   Guatemala  <=50K     61
# 14     28                       Haiti  <=50K     40
# 15     30          Holand-Netherlands  <=50K      1
# 16     31                    Honduras  <=50K     12
# ...

# %%
df_country.reset_index()
# Out:
#     index              native-country    age
# 0       0                           ?    583
# 1       1                    Cambodia     19
# 2       2                      Canada    121
# 3       3                       China     75
# 4       4                    Columbia     59
# 5       5                        Cuba     95
# 6       6          Dominican-Republic     70
# 7       7                     Ecuador     28
# 8       8                 El-Salvador    106
# 9       9                     England     90
# 10     10                      France     29
# 11     11                     Germany    137
# 12     12                      Greece     29
# 13     13                   Guatemala     64
# 14     14                       Haiti     44
# 15     15          Holand-Netherlands      1
# 16     16                    Honduras     13
# 17     17                        Hong     20
# 18     18                     Hungary     13
# 19     19                       India    100
# ...

# %%
df_country_new = df_country.reset_index()
df_country_new.shape
# Out:
# (42, 3)

# %%
df_50k_new = df_50k.reset_index()
df_50k_new.shape
# Out:
# (42, 4)

# %%
df_country_50k = df_country_new.copy()

# %%
df_country_50k['<50k'] = df_50k_new['age']

# %%
df_country_50k.head()
# Out:
#    index native-country  age  <50k
# 0      0              ?  583   437
# 1      1       Cambodia   19    12
# 2      2         Canada  121    82
# 3      3          China   75    55
# 4      4       Columbia   59    57

# %%
df_country_50k.tail()
# Out:
#     index   native-country    age   <50k
# 37     37         Thailand     18     15
# 38     38  Trinadad&Tobago     19     17
# 39     39    United-States  29170  21999
# 40     40          Vietnam     67     62
# 41     41       Yugoslavia     16     10

# %%
df_country_50k['per'] = (df_country_50k['age'] - df_country_50k['<50k']) / df_country_50k['age'] * 100

# %%
df_country_50k.head()
# Out:
#    index native-country  age  <50k        per
# 0      0              ?  583   437  25.042882
# 1      1       Cambodia   19    12  36.842105
# 2      2         Canada  121    82  32.231405
# 3      3          China   75    55  26.666667
# 4      4       Columbia   59    57   3.389831

# %%
mask = df_country_50k['per'] == df_country_50k['per'].max()
df_ans = df_country_50k[mask]['native-country']

# %%
df_ans
# Out:
# 20    Iran
# Name: native-country, dtype: object

# %%
df_ans.iloc[0]
# Out:
# 'Iran'
